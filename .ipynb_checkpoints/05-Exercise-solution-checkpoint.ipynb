# %% [markdown]
# # Handin exercise for week 5: Pandas

# %% [markdown]
# ## Ex1 Use data from Danmarks Statistik - Databanken
# 1. Go to https://www.dst.dk/da/Statistik/brug-statistikken/muligheder-i-statistikbanken/api#testkonsol
# 2. Open 'Konsol' and click 'Start Konsol'
# 3. In the console at pt 1: choose 'Retrieve tables', pt 2: choose get request and json format and pt 3: execute:
#   1. check the result
#   2. in the code below this same get request is used to get information about all available data tables in 'databanken'.
# 4. Change pt. 1 in the console to 'Retrieve data', pt 2: 'get request' and Table id: 'FOLK1A', format: csv, delimiter: semicolon and click: 'Variable and value codes' and choose some sub categories (Hint: hover over the codes to see their meaning). Finally execute and see what data you get.
# 5. With data aggregation and data visualization answer the following questions:
#   1. What is the change in pct of divorced danes from 2008 to 2020?
#   2. Which of the 5 biggest cities has the highest percentage of 'Never Married' in 2020?
#   3. Show a bar chart of changes in marrital status in Copenhagen from 2008 till now
#   4. Show 2 plots in same figure: 'Married' and 'Never Married' for all ages in DK in 2020 (Hint: x axis is age from 0-125, y axis is how many people in the 2 categories). Add lengend to show names on graphs
#
# ## Ex2 Use another table (extra)
# Choose any of the other tables in 'databanken' to find interesting data.
# 1. Collect the data
# 2. Pose 5 or more interesing questions to the data
# 3. Answer the questions by aggregating the data
# 4. Illustrate the answers with visual plots

# %%
import pandas as pd 
url = 'https://api.statbank.dk/v1/tables'
dst = pd.read_json(url)
dst.to_csv('dk-stat-all-tables.csv', encoding='utf-8', index=False)
dst[:20]
# Out:
#           id                                               text   unit  \
# 0     FOLK1A                        Folketal den 1. i kvartalet  Antal
# 1    FOLK1AM                          Folketal den 1. i måneden  Antal
# 2      FOLK3                                 Folketal 1. januar  Antal
# 3   FOLK3FOD                                 Folketal 1. januar  Antal
# 4       BEF5                             Folketal pr. 1. januar  Antal
# 5         FT       Folketal (summariske tal fra folketællinger)  Antal
# 6        BY1                                 Folketal 1. januar  Antal
# 7        BY2                                 Folketal 1. januar  Antal
# 8        BY3                                 Folketal 1. januar      -
# 9        KM1                        Folketal den 1. i kvartalet  Antal
# 10     SOGN1                                 Folketal 1. januar  Antal
# 11    SOGN10                                 Folketal 1. januar  Antal
# 12      BEF4                                 Folketal 1. januar  Antal
# 13     BEF5F  Personer født på Færøerne og bosat i Danmark 1...  Antal
# 14     BEF5G  Personer født i Grønland og bosat i Danmark 1....  Antal
# 15     BEV22      Befolkningens udvikling (foreløbig opgørelse)  Antal
# 16    BEV107                            Befolkningens udvikling  Antal
# 17  KMSTA003                            Befolkningens udvikling  Antal
# 18    GALDER                                   Gennemsnitsalder   Gns.
# 19  KMGALDER                                   Gennemsnitsalder   Gns.
#
#                 updated firstPeriod latestPeriod  active  \
# 0   2022-08-11T08:00:00      2008K1       2022K3    True
# 1   2022-09-07T08:00:00     2021M10      2022M08    True
# 2   2022-02-11T08:00:00        2008         2022    True
# 3   2022-03-18T08:00:00        2008         2022    True
# 4   2022-02-11T08:00:00        1990         2022    True
# 5   2022-02-11T08:00:00        1769         2022    True
# 6   2022-05-27T08:00:00        2010         2022    True
# 7   2022-05-27T08:00:00        2010         2022    True
# 8   2022-07-14T08:00:00        2017         2022    True
# 9   2022-08-11T08:00:00      2007K1       2022K3    True
# 10  2022-02-17T08:00:00        2010         2022    True
# 11  2021-09-22T08:00:00        1925         2021    True
# 12  2022-05-16T08:00:00        1901         2022    True
# 13  2022-02-11T08:00:00        2008         2022    True
# 14  2022-02-11T08:00:00        2008         2022    True
# 15  2022-08-11T08:00:00      2007K2       2022K2    True
# 16  2022-02-11T08:00:00        2006         2021    True
# 17  2022-02-17T08:00:00        2015         2021    True
# 18  2022-02-11T08:00:00        2005         2022    True
# 19  2022-02-17T08:00:00        2007         2022    True
#
#                                             variables
# 0               [område, køn, alder, civilstand, tid]
# 1                           [område, køn, alder, tid]
# 2          [fødselsdag, fødselsmåned, fødselsår, tid]
# 3           [fødselsdag, fødselsmåned, fødeland, tid]
# 4                         [køn, alder, fødeland, tid]
# 5                               [hovedlandsdele, tid]
# 6      [byområder og landdistrikter, alder, køn, tid]
# 7             [kommune, bystørrelse, alder, køn, tid]
# 8   [byområder og landdistrikter, folketal, areal ...
# 9                  [sogn, folkekirkemedlemsskab, tid]
# 10                            [sogn, køn, alder, tid]
# 11                                        [sogn, tid]
# 12                                         [øer, tid]
# 13            [køn, alder, forældrenes fødested, tid]
# 14            [køn, alder, forældrenes fødested, tid]
# 15                  [område, bevægelsesart, køn, tid]
# 16                  [område, bevægelsesart, køn, tid]
# 17                            [sogn, bevægelser, tid]
# 18                                [kommune, køn, tid]
# 19                                   [sogn, køn, tid]

# %% [markdown]
# ### With data aggregation and data visualization answer the following questions:

# %% [markdown]
#   1. What is the change in pct of divorced danes from 2008 to 2020?

# %%
import pandas as pd 
url = 'https://api.statbank.dk/v1/data/FOLK1A/CSV?delimiter=Semicolon&Tid=%3E%3D2008K1%3C%3D2020K4&CIVILSTAND=F'
dst = pd.read_csv(url, sep=';')
dst.to_csv('dk-stat-all-tables.csv', encoding='utf-8', index=False)
dst
# Out:
#        TID CIVILSTAND  INDHOLD
# 0   2008K1   Fraskilt   428864
# 1   2008K2   Fraskilt   431550
# 2   2008K3   Fraskilt   432713
# 3   2008K4   Fraskilt   432156
# 4   2009K1   Fraskilt   434233
# 5   2009K2   Fraskilt   437466
# 6   2009K3   Fraskilt   439378
# 7   2009K4   Fraskilt   439428
# 8   2010K1   Fraskilt   441913
# 9   2010K2   Fraskilt   444765
# 10  2010K3   Fraskilt   446333
# 11  2010K4   Fraskilt   447258
# 12  2011K1   Fraskilt   449609
# 13  2011K2   Fraskilt   453640
# 14  2011K3   Fraskilt   455105
# 15  2011K4   Fraskilt   455846
# 16  2012K1   Fraskilt   458430
# 17  2012K2   Fraskilt   462738
# 18  2012K3   Fraskilt   465210
# 19  2012K4   Fraskilt   466356
# 20  2013K1   Fraskilt   468891
# 21  2013K2   Fraskilt   473292
# 22  2013K3   Fraskilt   476507
# 23  2013K4   Fraskilt   477056
# 24  2014K1   Fraskilt   486336
# 25  2014K2   Fraskilt   492909
# 26  2014K3   Fraskilt   497069
# 27  2014K4   Fraskilt   500795
# 28  2015K1   Fraskilt   504505
# 29  2015K2   Fraskilt   506621
# 30  2015K3   Fraskilt   509922
# 31  2015K4   Fraskilt   513060
# 32  2016K1   Fraskilt   516864
# 33  2016K2   Fraskilt   520775
# 34  2016K3   Fraskilt   525180
# 35  2016K4   Fraskilt   526340
# 36  2017K1   Fraskilt   529457
# 37  2017K2   Fraskilt   533905
# 38  2017K3   Fraskilt   534656
# 39  2017K4   Fraskilt   535372
# 40  2018K1   Fraskilt   537834
# 41  2018K2   Fraskilt   541010
# 42  2018K3   Fraskilt   541999
# 43  2018K4   Fraskilt   542280
# 44  2019K1   Fraskilt   545085
# 45  2019K2   Fraskilt   545597
# 46  2019K3   Fraskilt   544731
# 47  2019K4   Fraskilt   543846
# 48  2020K1   Fraskilt   544588
# 49  2020K2   Fraskilt   548229
# 50  2020K3   Fraskilt   550715
# 51  2020K4   Fraskilt   552419

# %%
current = 552419
previous = 428864
change = (abs(current - previous) / previous) * 100.0
            
print('Percent increase from 2008K1 to 2020K4:\n',change)
# Out:
# Percent increase from 2008K1 to 2020K4:
#  28.809832487688404

# %% [markdown]
# 2. Which of the 5 biggest cities has the highest percentage of 'Never Married' in 2020?

# %%
import pandas as pd 
url = 'https://api.statbank.dk/v1/data/FOLK1A/CSV?delimiter=Semicolon&Tid=2020K4&OMR%C3%85DE=000%2C*&CIVILSTAND=U'
dst = pd.read_csv(url, sep=';')
dst.to_csv('dk-stat-all-tables.csv', encoding='utf-8', index=False)
dst_sorted = dst.sort_values(by='INDHOLD', ascending=False)
print(dst_sorted[:11])
np.max(dst['INDHOLD'])
# Out:
#         TID              OMRÅDE CIVILSTAND  INDHOLD
# 0    2020K4         Hele landet      Ugift  2859116
# 1    2020K4  Region Hovedstaden      Ugift   981652
# 73   2020K4  Region Midtjylland      Ugift   657563
# 50   2020K4   Region Syddanmark      Ugift   568943
# 2    2020K4           København      Ugift   417782
# 32   2020K4     Region Sjælland      Ugift   369548
# 93   2020K4  Region Nordjylland      Ugift   281410
# 84   2020K4              Aarhus      Ugift   211863
# 104  2020K4             Aalborg      Ugift   120226
# 58   2020K4              Odense      Ugift   113639
# 3    2020K4       Frederiksberg      Ugift    61020
# 2859116

# %% [markdown]
# 3. Show a bar chart of changes in marrital status in Copenhagen from 2008 till now

# %%
import pandas as pd 
import matplotlib.pyplot as plt

#url = 'https://api.statbank.dk/v1/data/FOLK1A/CSV?delimiter=Semicolon&Tid=2008K1%2C2022K3&CIVILSTAND=U%2CG%2CE%2CF'
url = 'https://api.statbank.dk/v1/data/FOLK1A/CSV?delimiter=Semicolon&Tid=%3E%3D2008K1%3C%3D2020K4&CIVILSTAND=U%2CG%2CE%2CF'
dst = pd.read_csv(url, sep=';')
dst.to_csv('dk-stat-all-tables.csv', encoding='utf-8', index=False)

dst.plot.bar(x='TID', y = 'INDHOLD', rot=0);

# %% [markdown]
#   4. Show 2 plots in same figure: 'Married' and 'Never Married' for all ages in DK in 2020 (Hint: x axis is age from 0-125, y axis is how many people in the 2 categories). Add lengend to show names on graphs

# %%
#DoStuff

# %% [markdown]
# ## Class Exercise: Read Titanic dataset and do some munging
#
# 1. read titanic data from the data/titanic_train.csv file into a pandas dataframe
# 2. set index of the dataframe to passenger id
# 3. sort the dataframe by 'fare' (price of ticket)
# 4. write a function to reformat a name to only contain "firstname lastname" (look for current format in the name column)
# 5. use df.apply() to Change all names to the "firstname lastname" format
# 6. Get only last name by the use of str method split() on comma. https://pandas.pydata.org/docs/user_guide/text.html#splitting-and-replacing-strings
# 7. Get only those passengers that had one of these ticket numbers: `[350406,248706,382652,244373,345763,2649,239865]`
# 8. Remove all rows without and age
# 9. Convert age values to integer
# 10. get only the children from the dataset
# 11. Filter to get only passengers with a valid cabin
# 12. Change Embarked to full name of port: C = Cherbourg; Q = Queenstown; S = Southampton
# 13. create new column: 'relations' that adds sibling/spouse value with parent/child values
# 14. Is there a relationship between how many relations and chances of survival?

# %%
import pandas as pd

df = pd.read_csv('data/titanic_train.csv')
pd.DataFrame(df)
new_Df = df.sort_values('Fare', ascending=False)
new_Df.set_index('PassengerId')
print(new_Df)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 27            28         0       1      Fortune, Mr. Charles Alexander
# ..           ...       ...     ...                                 ...
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 413          414         0       2      Cunningham, Mr. Alfred Fleming
# 822          823         0       1     Reuchlin, Jonkheer. John George
# 732          733         0       2                Knight, Mr. Robert J
# 674          675         0       2          Watson, Mr. Ennis Hastings
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 88   female  23.0      3      2     19950  263.0000  C23 C25 C27        S
# 27     male  19.0      3      2     19950  263.0000  C23 C25 C27        S
# ..      ...   ...    ...    ...       ...       ...          ...      ...
# 633    male   NaN      0      0    112052    0.0000          NaN        S
# 413    male   NaN      0      0    239853    0.0000          NaN        S
# 822    male  38.0      0      0     19972    0.0000          NaN        S
# 732    male   NaN      0      0    239855    0.0000          NaN        S
# 674    male   NaN      0      0    239856    0.0000          NaN        S
#
# [891 rows x 12 columns]

# %% [markdown]
# 4. write a function to reformat a name to only contain "firstname lastname" (look for current format in the name column)
# 5. use df.apply() to Change all names to the "firstname lastname" format

# %%
#Fra Vincent på Python Discord kanalen:

def reformat_name(name):
    first_name = name.split(', ')[1].split(' ')[1].strip()
    last_name = name.split(',')[0].strip()
    
    return f'{first_name} {last_name}'

df['Name'] = df['Name'].apply(reformat_name)

print(df)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [26], in <cell line: 9>()
#       5     last_name = name.split(',')[0].strip()
#       7     return f'{first_name} {last_name}'
# ----> 9 df['Name'] = df['Name'].apply(reformat_name)
#      11 print(df)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/apply.py:1088, in SeriesApply.apply(self)
#    1084 if isinstance(self.f, str):
#    1085     # if we are a string, try to dispatch
#    1086     return self.apply_str()
# -> 1088 return self.apply_standard()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/apply.py:1143, in SeriesApply.apply_standard(self)
#    1137         values = obj.astype(object)._values
#    1138         # error: Argument 2 to "map_infer" has incompatible type
#    1139         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1140         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1141         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1142         # "Callable[[Any], Any]"
# -> 1143         mapped = lib.map_infer(
#    1144             values,
#    1145             f,  # type: ignore[arg-type]
#    1146             convert=self.convert_dtype,
#    1147         )
#    1149 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1150     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1151     #  See also GH#25959 regarding EA support
#    1152     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# Input In [26], in reformat_name(name)
#       3 def reformat_name(name):
# ----> 4     first_name = name.split(', ')[1].split(' ')[1].strip()
#       5     last_name = name.split(',')[0].strip()
#       7     return f'{first_name} {last_name}'
#
# IndexError: list index out of range

# %%
def get_lastname(name):
    lastname = name.split(',')[0].strip()
    
    return f'{lastname}'
                          
df['Name'] = df['Name'].apply(get_lastname)

print(df)
# Out:
#      PassengerId  Survived  Pclass                Name     Sex   Age  SibSp  \
# 0              1         0       3         Owen Braund    male  22.0      1
# 1              2         1       1        John Cumings  female  38.0      1
# 2              3         1       3     Laina Heikkinen  female  26.0      0
# 3              4         1       1    Jacques Futrelle  female  35.0      1
# 4              5         0       3       William Allen    male  35.0      0
# ..           ...       ...     ...                 ...     ...   ...    ...
# 886          887         0       2     Juozas Montvila    male  27.0      0
# 887          888         1       1     Margaret Graham  female  19.0      0
# 888          889         0       3  Catherine Johnston  female   NaN      1
# 889          890         1       1           Karl Behr    male  26.0      0
# 890          891         0       3      Patrick Dooley    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# 7. Get only those passengers that had one of these ticket numbers: `[350406,248706,382652,244373,345763,2649,239865]`

# %%
def get_people_with_ticket():
    
    df_filtered = df[df['Ticket'].isin([350406,248706,382652,244373,345763,2649,239865])]
    
    #df_phones[df_phones['Number'].isin(['+4598877665','+4543543456'])]
    print(df_filtered)
    
get_people_with_ticket()
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df['Relations'] = df['SibSp'] + df['Parch']
df
# Out:
#      PassengerId  Survived  Pclass                Name     Sex   Age  SibSp  \
# 0              1         0       3         Owen Braund    male  22.0      1
# 1              2         1       1        John Cumings  female  38.0      1
# 2              3         1       3     Laina Heikkinen  female  26.0      0
# 3              4         1       1    Jacques Futrelle  female  35.0      1
# 4              5         0       3       William Allen    male  35.0      0
# ..           ...       ...     ...                 ...     ...   ...    ...
# 886          887         0       2     Juozas Montvila    male  27.0      0
# 887          888         1       1     Margaret Graham  female  19.0      0
# 888          889         0       3  Catherine Johnston  female   NaN      1
# 889          890         1       1           Karl Behr    male  26.0      0
# 890          891         0       3      Patrick Dooley    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  Relations
# 0        0         A/5 21171   7.2500   NaN        S          1
# 1        0          PC 17599  71.2833   C85        C          1
# 2        0  STON/O2. 3101282   7.9250   NaN        S          0
# 3        0            113803  53.1000  C123        S          1
# 4        0            373450   8.0500   NaN        S          0
# ..     ...               ...      ...   ...      ...        ...
# 886      0            211536  13.0000   NaN        S          0
# 887      0            112053  30.0000   B42        S          0
# 888      2        W./C. 6607  23.4500   NaN        S          3
# 889      0            111369  30.0000  C148        C          0
# 890      0            370376   7.7500   NaN        Q          0
#
# [891 rows x 13 columns]
